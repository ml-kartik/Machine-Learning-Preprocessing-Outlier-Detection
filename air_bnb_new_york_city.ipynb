# %%
import pandas as pd
df = pd.read_csv("AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df["price_per_night"] = df["price"]/df["minimum_nights"]
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
min_threshold , max_threshold = df.price_per_night.quantile([0.01,0.99])
min_threshold , max_threshold
# Out:
# (1.2333333333333334, 443.0)

# %%
df[ df["price_per_night"]>max_threshold ]
# Out:
#              id                                               name    host_id  \
# 85        19601                perfect for a family or small group      74303
# 418      141335                             Architect's Brownstone     687361
# 1019     414801   Industrial Brooklyn Loft with Tree-Lined Windows     319077
# 1105     468613   $ (Phone number hidden by Airbnb) weeks - room f    2325861
# 1553     702551      UWS renovated 2bedroom 2bath near everything.    3606458
# ...         ...                                                ...        ...
# 48343  36207223                   Sunny, Spacious 2-bd Chelsea Apt    5723770
# 48495  36282795              Brooklyn hot party place with jaccuzi  270554496
# 48523  36308562  Tasteful & Trendy Brooklyn Brownstone, near Train  217732163
# 48535  36311055     Stunning & Stylish Brooklyn Luxury, near Train  245712163
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
# ...

# %%
max_threshold
# Out:
# 443.0

# %%
df[df["price_per_night"]<min_threshold]
# Out:
#              id                                               name    host_id  \
# 36        11452                        Clean and Quiet in Brooklyn       7355
# 245       61509                Quiet, clean midtown apt w. elevato      23619
# 349       94209                 LARGE 1BR (CONV 2BR) CROWN HEIGHTS     503800
# 441      152520                Female Only Clean15min to Manhattan     733894
# 457      161366                 Sunny 15min to Manhattan LADY only     733894
# ...         ...                                                ...        ...
# 48636  36351543              2-MONTH SUBLEASE (WITH EARLY MOVE-IN)   52984497
# 48753  36418759  Spacious Room w/ AC, Laundry, WiFi + Free Clea...  154980356
# 48772  36424129   Bright & Cheerful! Modern w/ Laundry + Fast WiFi  107407045
# 48774  36424334   Laundry + Central AC - Modern Style - Near Metro  155298656
# 48871  36475746      A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
#
# ...

# %%
df1 = df[(df["price_per_night"]<max_threshold)  &  (df["price_per_night"]>min_threshold)]

# %%
df1.shape
# Out:
# (47898, 17)

# %%
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.isna().sum()
# Out:
# id                                   0
# name                                15
# host_id                              0
# host_name                           21
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9594
# reviews_per_month                 9594
# calculated_host_listings_count       0
# availability_365                     0
# price_per_night                      0
# dtype: int64

# %%
df1.dropna()
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
df1.isna().sum()
# Out:
# id                                   0
# name                                15
# host_id                              0
# host_name                           21
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9594
# reviews_per_month                 9594
# calculated_host_listings_count       0
# availability_365                     0
# price_per_night                      0
# dtype: int64
