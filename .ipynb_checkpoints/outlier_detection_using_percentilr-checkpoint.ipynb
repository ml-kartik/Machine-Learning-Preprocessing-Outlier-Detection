# %%
import pandas as pd
df = pd.read_csv("name_height_outlier.csv")
df
# Out:
#               Name  Height_cm
# 0     Aarav Sharma        172
# 1      Priya Patel        160
# 2      Rohan Mehta        178
# 3     Ananya Singh        165
# 4       Vikram Rao        181
# 5       Neha Gupta        158
# 6       Arjun Nair        175
# 7       Sneha Iyer        162
# 8      Karan Verma        169
# 9       Isha Desai        157
# 10    Rahul Kapoor        174
# 11     Meera Joshi        163
# 12    Dev Malhotra        400
# 13  Pooja Kulkarni        159
# 14      Aditya Sen        176

# %%
max_threshold = df["Height_cm"].quantile(0.95) #finds the 95th percentile value.
max_threshold
# Out:
# np.float64(246.69999999999976)

# %%
df[df['Height_cm']>max_threshold]
# Out:
#             Name  Height_cm
# 12  Dev Malhotra        400

# %%
min_threshold = df["Height_cm"].quantile(0.05) #finds the 95th percentile value.
min_threshold
# Out:
# np.float64(157.7)

# %%
df[df['Height_cm']<min_threshold]
# Out:
#          Name  Height_cm
# 9  Isha Desai        157

# %%
df[df[]]
